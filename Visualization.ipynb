# %% [markdown]
# <a href="https://colab.research.google.com/github/jalalbamniya/DataSet/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Visualization**
#
# Importing used libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Datasate Read csv file

# %%
data_vs=pd.read_csv("/content/penguins.cv.csv")
data_vs
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
data_vs.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
data_vs.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
data_vs.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
data_vs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
data_vs.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
data_vs['sex'] = data_vs['sex'].replace(np.nan, 0)
data_vs['bill_length_mm']=data_vs["bill_length_mm"].replace(np.nan, 0)
data_vs['bill_depth_mm']=data_vs["bill_depth_mm"].replace(np.nan, 0)
data_vs['flipper_length_mm']=data_vs["flipper_length_mm"].replace(np.nan, 0)
data_vs['body_mass_g']=data_vs["body_mass_g"].replace(np.nan, 0)

# %%
data_vs.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
data_vs.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      344.000000     344.000000         344.000000   344.000000
# mean        43.666570      17.051453         199.747093  4177.325581
# std          6.388776       2.362696          20.750566   861.234942
# min          0.000000       0.000000           0.000000     0.000000
# 25%         39.200000      15.500000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4025.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# # **Data Visualization**

# %%
numerical_float64 = (data_vs.dtypes == "float64")
numerical_float64_list = list(numerical_float64[numerical_float64].index)

print("Numerical variables:")
print(numerical_float64_list)
# Out:
# Numerical variables:
# ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']

# %%
def plot_hist(variable):
    plt.figure(figsize = (9,3))
    plt.hist(data_vs[variable], bins = 50)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} Distribution with Histogram".format(variable))
    plt.show()

# %%
for n in numerical_float64_list:
    plot_hist(n)

# %%
cols = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
sns.pairplot(data_vs[cols])

# %%
sns.pairplot(data_vs, hue = 'species')

# %%
plt.figure(figsize=(12,8)) 
sns.heatmap(data_vs.corr(), annot=True, cmap='Dark2_r', linewidths = 2)
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.barplot(x = 'species', y = 'bill_length_mm', data = data_vs, palette="cubehelix")
plt.subplot(2,2,2)
sns.barplot(x = 'species', y = 'bill_depth_mm', data = data_vs, palette="Oranges")
plt.subplot(2,2,3)
sns.barplot(x = 'species', y = 'flipper_length_mm', data = data_vs, palette="Oranges")
plt.subplot(2,2,4)
sns.barplot(x = 'species', y = 'body_mass_g', data = data_vs, palette="cubehelix")

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.violinplot(x = 'species', y = 'bill_length_mm', data = data_vs, palette="rocket_r")
plt.subplot(2,2,2)
sns.violinplot(x = 'species', y = 'bill_depth_mm', data = data_vs, palette="rocket_r")
plt.subplot(2,2,3)
sns.violinplot(x = 'species', y = 'flipper_length_mm', data = data_vs, palette="rocket_r")
plt.subplot(2,2,4)
sns.violinplot(x = 'species', y = 'body_mass_g', data = data_vs, palette="rocket_r")

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.boxplot(x = 'species', y = 'bill_length_mm', data = data_vs, palette="gist_ncar_r")
plt.subplot(2,2,2)
sns.boxplot(x = 'species', y = 'bill_depth_mm', data = data_vs, palette="gist_ncar_r")
plt.subplot(2,2,3)
sns.boxplot(x = 'species', y = 'flipper_length_mm', data = data_vs, palette="gist_ncar_r")
plt.subplot(2,2,4)
sns.boxplot(x = 'species', y = 'body_mass_g', data = data_vs, palette="gist_ncar_r")

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.distplot(data_vs['bill_length_mm'], color="red").set_title('bill_length_mm Interval')
plt.subplot(2,2,2)
sns.distplot(data_vs['bill_depth_mm'], color="green").set_title('bill_depth_mm Interval')
plt.subplot(2,2,3)
sns.distplot(data_vs['flipper_length_mm'], color="blue").set_title('flipper_length_mm Interval')
plt.subplot(2,2,4)
sns.distplot(data_vs['body_mass_g'], color="black").set_title('body_mass_g Interval')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(1, figsize=(5,5))
plt.title("Distribution of Species")
data_vs['species'].value_counts().plot.pie(autopct="%1.1f%%")
